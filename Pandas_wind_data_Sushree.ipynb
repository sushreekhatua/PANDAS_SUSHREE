# %% [markdown]
# ### Wind Data
# - dataset :wind.data

# %%
import pandas as pd

# %%
wind=pd.read_csv("C:/Users/sushr/Downloads/wind.data", sep="\s+", parse_dates= {"DATE": ["Yr", "Mo", "Dy"]}, keep_date_col = True)
wind.head()
# Out:
#         DATE  Yr Mo Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# 0 2061-01-01  61  1  1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 1 2061-01-02  61  1  2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 2 2061-01-03  61  1  3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 3 2061-01-04  61  1  4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 4 2061-01-05  61  1  5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
#      MUL    CLO    BEL    MAL
# 0  10.83  12.58  18.50  15.04
# 1   9.79   9.67  17.54  13.83
# 2   8.50   7.67  12.75  12.71
# 3   5.83   5.88   5.46  10.88
# 4  10.92  10.34  12.92  11.83

# %%
# Another way to load the dataset
# wind_data=pd.read_csv("C:/Users/sushr/Downloads/wind.data",sep="\s+")

# %%
wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    6574 non-null   datetime64[ns]
#  1   Yr      6574 non-null   object
#  2   Mo      6574 non-null   object
#  3   Dy      6574 non-null   object
#  4   RPT     6568 non-null   float64
#  5   VAL     6571 non-null   float64
#  6   ROS     6572 non-null   float64
#  7   KIL     6569 non-null   float64
#  8   SHA     6572 non-null   float64
#  9   BIR     6574 non-null   float64
#  10  DUB     6571 non-null   float64
#  11  CLA     6572 non-null   float64
#  12  MUL     6571 non-null   float64
#  13  CLO     6573 non-null   float64
#  14  BEL     6574 non-null   float64
#  15  MAL     6570 non-null   float64
# dtypes: datetime64[ns](1), float64(12), object(3)
# memory usage: 821.9+ KB

# %% [markdown]
# ### Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=wind.drop(columns=["Yr","Mo","Dy"])

# %%
data.head()
# Out:
#         DATE    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
# other way
# wind_data["date"] = wind_data.Yr.astype(
# str)+"-"+wind_data.Mo.astype(str)+"-"+wind_data.Dy.astype(str)
#wind_data["date"]=pd.to_datetime(wind_data["date"], format="%y-%m-%d")

# %% [markdown]
# ### Create a function to fix the year from 2061 to 1961 and apply it.

# %%
# Another approach to solve this question
#conv_to_1961 = lambda x : x -  pd.DateOffset(years=100) if x.year>=2061 else x
# data.Date.apply(conv_to_1961)

# %%
import datetime
wind_data = pd.read_csv("C:/Users/sushr/Downloads/wind.data", sep="\s+", parse_dates={"DATE": ["Yr", "Mo", "Dy"]}, date_parser = lambda x, y, z: (datetime.datetime.strptime("19"+x+"-"+y+"-"+z, "%Y-%m-%d")), keep_date_col=True)

# %%
wind_data
# Out:
#            DATE  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0    1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1    1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2    1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3    1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4    1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ...  ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# ...

# %%
# another way
#wind_data["date"] = "19"+wind_data.Yr.astype(str)+"-"+wind_data.Mo.astype(str)+"-"+wind_data.Dy.astype(str)
#wind_data["date"] = pd.to_datetime(wind_data["date"], format="%Y-%m-%d")
# wind_data.head()

# %% [markdown]
# ### Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
wind_data.set_index("DATE",inplace=True)

# %%
wind_data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='DATE', length=6574, freq=None)

# %%
wind_data.head()
# Out:
#             Yr Mo Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# DATE
# 1961-01-01  61  1  1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 1961-01-02  61  1  2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 1961-01-03  61  1  3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 1961-01-04  61  1  4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 1961-01-05  61  1  5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
#               MUL    CLO    BEL    MAL
# DATE
# 1961-01-01  10.83  12.58  18.50  15.04
# 1961-01-02   9.79   9.67  17.54  13.83
# 1961-01-03   8.50   7.67  12.75  12.71
# 1961-01-04   5.83   5.88   5.46  10.88
# 1961-01-05  10.92  10.34  12.92  11.83

# %% [markdown]
# ### Compute how many values are missing for each location over the entire record.

# %%
wind_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1978-12-31
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Yr      6574 non-null   object
#  1   Mo      6574 non-null   object
#  2   Dy      6574 non-null   object
#  3   RPT     6568 non-null   float64
#  4   VAL     6571 non-null   float64
#  5   ROS     6572 non-null   float64
#  6   KIL     6569 non-null   float64
#  7   SHA     6572 non-null   float64
#  8   BIR     6574 non-null   float64
#  9   DUB     6571 non-null   float64
#  10  CLA     6572 non-null   float64
#  11  MUL     6571 non-null   float64
#  12  CLO     6573 non-null   float64
#  13  BEL     6574 non-null   float64
#  14  MAL     6570 non-null   float64
# dtypes: float64(12), object(3)
# memory usage: 1.1+ MB

# %%
wind_data.isna().sum()
# Out:
# Yr     0
# Mo     0
# Dy     0
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Compute how many non-missing values there are in total.

# %%
(wind_data.loc[:, "RPT":"MAL"].isna() == False).sum().sum()
# Out:
# 78857

# %% [markdown]
# ### Calculate the mean windspeeds of the windspeeds over all the locations and all the times. ie a single number for enire dataset

# %%
x=wind_data.loc[:, "RPT":"MAL"]

# %%
x.mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %%
# calculate the mean of all the columns along rows or axis=1
# x.mean(axis=1)
# We need to calculate mean value for all the time i.e.for each date,we need to calculate mean for every place
x.mean(1)
# Out:
# DATE
# 1961-01-01    13.018182
# 1961-01-02    11.336364
# 1961-01-03    11.641818
# 1961-01-04     6.619167
# 1961-01-05    10.630000
#                 ...
# 1978-12-27    16.708333
# 1978-12-28    15.150000
# 1978-12-29    14.890000
# 1978-12-30    15.367500
# 1978-12-31    15.402500
# Length: 6574, dtype: float64

# %%
# mean value for entire dataframe
x.mean(1).mean()
# Out:
# 10.228284167350386

# %% [markdown]
# ### Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.

# %%
day_stats=x.describe()

# %%
day_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %% [markdown]
# ### Find the average windspeed in January for each location.

# %%
wind_data[wind_data.index.month==1].loc[:,"RPT":"MAL"].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Downsample the record to a yearly frequency for each location.

# %%
ds=wind_data.resample(rule="A")

# %%
ds.mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# DATE
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# ### Downsample the record to a monthly frequency for each location.

# %%
ds = wind_data.resample("M")

# %%
ds.mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# DATE
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
# different approach
wind_data.groupby(wind_data.index.to_period("M")).mean()
# Out:
#                RPT        VAL        ROS       KIL        SHA        BIR  \
# DATE
# 1961-01  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...            ...        ...        ...       ...        ...        ...
# 1978-08   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
#                DUB        CLA        MUL        CLO        BEL        MAL
# DATE
# ...

# %% [markdown]
# ### Downsample the record to a weekly frequency for each location.

# %%
ds=wind_data.resample("W")
ds.mean()
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# DATE
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
# different approach
wind_data.groupby(wind_data.index.to_period("W")).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# DATE
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %% [markdown]
# ### Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
ds=wind_data.resample("W",loffset=pd.Timedelta(1,"D"))
ds.agg(["min","max","mean","std"])
# Out:
# <ipython-input-192-3b1afdeea2c9>:1: FutureWarning: 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
#
#   ds=wind_data.resample("W",loffset=pd.Timedelta(1,"D"))
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# DATE
# 1961-01-02  15.04  15.04  15.040000       NaN  14.96  14.96  14.960000
# 1961-01-09  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-16   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-23   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-30  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# ...           ...    ...        ...       ...    ...    ...        ...
# ...

# %% [markdown]
# ### What is the year with most occurrences?

# %%
wind_data.resample("Y").mean().mean(1).idxmax().year
# Out:
# 1963
