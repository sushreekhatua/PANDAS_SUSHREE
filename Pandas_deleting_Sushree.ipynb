# %% [markdown]
# ## Import the dataset from a address and assign it to a variable called wine

# %%
import pandas as pd

# %%
wine=pd.read_table("C:/Users/sushr/Downloads/wine.data",sep=",")
wine
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %% [markdown]
# ### Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(wine.columns[[0, 3, 6, 8, 10, 12, 13]], axis=1, inplace=True)
wine
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### Assign the columns as below:
# - 1) alcohol
# - 2) malic_acid
# - 3) alcalinity_of_ash
# - 4) magnesium
# - 5) flavanoids
# - 6) proanthocyanins
# - 7) hue

# %%
# by columns attribute
wine.columns = ["alcohol",
                "malic_acid",
                "alcalinity_of_ash",
                "magnesium",
                "flavanoids",
                "proanthocyanins",
                "hue"]
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Set the values of the first 3 rows from alcohol as NaN

# %%
import numpy as np
wine["alcohol"].iloc[:3]=np.nan
wine.head()
# Out:
# C:\Users\sushr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2        100        2.76
# 1        NaN        2.36               18.6        101        3.24
# 2        NaN        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %%
wine["magnesium"][2:4]=np.nan
wine
# Out:
# <ipython-input-49-d479bd7529c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine["magnesium"][2:4]=np.nan
# C:\Users\sushr\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2      100.0        2.76
# 1        NaN        2.36               18.6      101.0        3.24
# 2        NaN        1.95               16.8        NaN        3.49
# ...

# %% [markdown]
# ### Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine["alcohol"]=wine["alcohol"].fillna(10)
wine["magnesium"]=wine["magnesium"].fillna(100)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %%
# Another way 
# wine.fillna({"alcohol":10,"magnesium":100},inplace=True

# %% [markdown]
# ### Count the number of missing values

# %%
wine.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Create an array of 10 random numbers up until 10

# %%
a=np.random.randint(0,178,10)
a
# Out:
# array([ 98, 136,   9,  51, 113,  30,  27,  56, 142,  96])

# %% [markdown]
# ### random numbers you generated as an index and assign NaN value to each of cell.

# %%
import numpy as np
wine.iloc[a]=np.nan

# %%
wine.head(40)
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0     10.00        1.78               11.2      100.0        2.76
# 1     10.00        2.36               18.6      101.0        3.24
# 2     10.00        1.95               16.8      100.0        3.49
# 3     13.24        2.59               21.0      100.0        2.69
# 4     14.20        1.76               15.2      112.0        3.39
# 5     14.39        1.87               14.6       96.0        2.52
# 6     14.06        2.15               17.6      121.0        2.51
# 7     14.83        1.64               14.0       97.0        2.98
# 8     13.86        1.35               16.0       98.0        3.15
# 9       NaN         NaN                NaN        NaN         NaN
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
# 12    14.75        1.73               11.4       91.0        3.69
# ...

# %% [markdown]
# ### How many missing values do we have?

# %%
wine.isna().sum()
# Out:
# alcohol              10
# malic_acid           10
# alcalinity_of_ash    10
# magnesium            10
# flavanoids           10
# proanthocyanins      10
# hue                  10
# dtype: int64

# %% [markdown]
# ### Delete the rows that contain missing values

# %%
wine.dropna(axis=0,how="any",inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      10.00        2.36               18.6      101.0        3.24
# 2      10.00        1.95               16.8      100.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4      14.20        1.76               15.2      112.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Print only the non-null values in alcohol

# %%
x=pd.notnull(wine["alcohol"])
wine[x].alcohol
# Out:
# 0      10.00
# 1      10.00
# 2      10.00
# 3      13.24
# 4      14.20
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 167, dtype: float64

# %% [markdown]
# ### Reset the index, so it starts with 0 again

# %%
wine.reset_index(inplace=True)
wine=wine.drop(columns="index")
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      10.00        2.36               18.6      101.0        3.24
# 2      10.00        1.95               16.8      100.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4      14.20        1.76               15.2      112.0        3.39
# ..       ...         ...                ...        ...         ...
# 162    13.71        5.65               20.5       95.0        0.61
# 163    13.40        3.91               23.0      102.0        0.75
# 164    13.27        4.28               20.0      120.0        0.69
# 165    13.17        2.59               20.0      120.0        0.68
# 166    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...
